# %% [markdown]
# # Central Tendency

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset1
dataset1 = pd.read_csv('analyzed_previous_application_data.csv')

# %% [markdown]
# # find mean, median, mode find IQR(interquartile Range), min and max ans lesser and greater IQR!

# %%
# Create a copy of the original dataset for comparison
original_dataset = dataset1.copy()

# Create a DataFrame to store descriptive statistics
descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', 'Q3:75%', 'Q4:100%', 'IQR', 'Lesser IQR', 'Greater IQR', 'min', 'max'], columns=dataset1.columns)

# Calculate additional statistics
for columnName in dataset1.columns:
    descriptive.loc["Mean", columnName] = dataset1[columnName].mean()
    descriptive.loc["Median", columnName] = dataset1[columnName].median()
    descriptive.loc["Mode", columnName] = dataset1[columnName].mode()[0]
    descriptive.loc['Q1:25%', columnName] = dataset1[columnName].quantile(0.25)
    descriptive.loc['Q2:50%', columnName] = dataset1[columnName].quantile(0.50)
    descriptive.loc['Q3:75%', columnName] = dataset1[columnName].quantile(0.75)
    descriptive.loc['min', columnName] = dataset1[columnName].min()
    descriptive.loc['max', columnName] = dataset1[columnName].max()
    descriptive.loc['Q4:100%', columnName] = dataset1[columnName].max()  # Add Q4:100% here

    iqr = descriptive.loc['Q3:75%', columnName] - descriptive.loc['Q1:25%', columnName]
    descriptive.loc['IQR', columnName] = iqr
    descriptive.loc['Lesser IQR', columnName] = descriptive.loc['Q1:25%', columnName] - 1.5 * iqr
    descriptive.loc['Greater IQR', columnName] = descriptive.loc['Q3:75%', columnName] + 1.5 * iqr

# %%
descriptive
# Out:
#                  SK_ID_PREV     SK_ID_CURR NAME_CONTRACT_TYPE   AMT_ANNUITY  \
# Mean         1923089.135331  278357.174099           0.668487  14906.506177
# Median            1923110.5       278714.5                1.0       11250.0
# Mode                1000001         187868                  0       11250.0
# Q1:25%           1461857.25       189329.0                0.0    7547.09625
# Q2:50%            1923110.5       278714.5                1.0       11250.0
# Q3:75%           2384279.75       367514.0                1.0   16824.02625
# Q4:100%             2845382         456255                  3    418058.145
# IQR                922422.5       178185.0                1.0       9276.93
# Lesser IQR          78223.5       -77948.5               -1.5   -6368.29875
# Greater IQR       3767913.5       634791.5                2.5   30739.42125
# min                 1000001         100001                  0           0.0
# max                 2845382         456255                  3    418058.145
#
#             AMT_APPLICATION     AMT_CREDIT AMT_DOWN_PAYMENT AMT_GOODS_PRICE  \
# Mean           175233.86036  196114.021218      3983.716917   201181.535209
# Median              71046.0        80541.0           1638.0        112320.0
# Mode                    0.0            0.0           1638.0        112320.0
# Q1:25%              18720.0        24160.5           1638.0         67500.0
# Q2:50%              71046.0        80541.0           1638.0        112320.0
# Q3:75%             180360.0       216418.5           1638.0        180405.0
# Q4:100%           6905160.0      6905160.0        3060045.0       6905160.0
# IQR                161640.0       192258.0              0.0        112905.0
# Lesser IQR        -223740.0      -264226.5           1638.0       -101857.5
# Greater IQR        422820.0       504805.5           1638.0        349762.5
# min                     0.0            0.0             -0.9             0.0
# max               6905160.0      6905160.0        3060045.0       6905160.0
#
#             WEEKDAY_APPR_PROCESS_START HOUR_APPR_PROCESS_START  ...  \
# Mean                           3.01226               12.484182  ...
# Median                             3.0                    12.0  ...
# Mode                                 5                      11  ...
# Q1:25%                             1.0                    10.0  ...
# Q2:50%                             3.0                    12.0  ...
# Q3:75%                             5.0                    15.0  ...
# Q4:100%                              6                      23  ...
# IQR                                4.0                     5.0  ...
# Lesser IQR                        -5.0                     2.5  ...
# Greater IQR                       11.0                    22.5  ...
# min                                  0                       0  ...
# max                                  6                      23  ...
#
#             NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# Mean                    6.737651   15.150574         1.823614
# Median                      10.0        12.0              1.0
# Mode                          10        12.0                0
# Q1:25%                       4.0        10.0              0.0
# Q2:50%                      10.0        12.0              1.0
# Q3:75%                      10.0        16.0              3.0
# Q4:100%                       10        84.0                4
# IQR                          6.0         6.0              3.0
# Lesser IQR                  -5.0         1.0             -4.5
# Greater IQR                 19.0        25.0              7.5
# min                            0         0.0                0
# max                           10        84.0                4
#
#             PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# Mean                   6.947847      351491.781614    7919.663964
# Median                      8.0           365243.0         -831.0
# Mode                          2           365243.0         -831.0
# Q1:25%                      2.0           365243.0        -1020.0
# Q2:50%                      8.0           365243.0         -831.0
# Q3:75%                     10.0           365243.0         -683.0
# Q4:100%                      16           365243.0       365243.0
# IQR                         8.0                0.0          337.0
# Lesser IQR                -10.0           365243.0        -1525.5
# Greater IQR                22.0           365243.0         -177.5
# min                           0            -2922.0        -2892.0
# max                          16           365243.0       365243.0
#
#             DAYS_LAST_DUE_1ST_VERSION DAYS_LAST_DUE DAYS_TERMINATION  \
# Mean                     20014.516502  45504.726178     48749.875304
# Median                         -361.0        -537.0           -499.0
# Mode                           -361.0        -537.0           -499.0
# Q1:25%                         -580.0        -734.0           -695.0
# Q2:50%                         -361.0        -537.0           -499.0
# Q3:75%                         -187.0        -371.0           -334.0
# Q4:100%                      365243.0      365243.0         365243.0
# IQR                             393.0         363.0            361.0
# Lesser IQR                    -1169.5       -1278.5          -1236.5
# Greater IQR                     402.5         173.5            207.5
# min                           -2801.0       -2889.0          -2874.0
# max                          365243.0      365243.0         365243.0
#
#             NFLAG_INSURED_ON_APPROVAL
# Mean                         0.198551
# Median                            0.0
# Mode                              0.0
# Q1:25%                            0.0
# Q2:50%                            0.0
# Q3:75%                            0.0
# Q4:100%                           1.0
# IQR                               0.0
# Lesser IQR                        0.0
# Greater IQR                       0.0
# min                               0.0
# max                               1.0
#
# [12 rows x 37 columns]

# %% [markdown]
# # Check Outliers

# %%
lesser = []
greater = []
# Check for outliers
for columnName in dataset1:
    if  descriptive.loc['Lesser IQR', columnName] > descriptive.loc['min', columnName]:
        lesser.append(columnName)

    if  descriptive.loc['Greater IQR', columnName] < descriptive.loc['max', columnName]:
        greater.append(columnName)

# %%
lesser
# Out:
# ['AMT_DOWN_PAYMENT',
#  'HOUR_APPR_PROCESS_START',
#  'FLAG_LAST_APPL_PER_CONTRACT',
#  'NFLAG_LAST_APPL_IN_DAY',
#  'RATE_DOWN_PAYMENT',
#  'RATE_INTEREST_PRIMARY',
#  'RATE_INTEREST_PRIVILEGED',
#  'NAME_CASH_LOAN_PURPOSE',
#  'DAYS_DECISION',
#  'CODE_REJECT_REASON',
#  'NAME_TYPE_SUITE',
#  'NAME_PORTFOLIO',
#  'CHANNEL_TYPE',
#  'CNT_PAYMENT',
#  'DAYS_FIRST_DRAWING',
#  'DAYS_FIRST_DUE',
#  'DAYS_LAST_DUE_1ST_VERSION',
#  'DAYS_LAST_DUE',
#  'DAYS_TERMINATION']

# %%
greater
# Out:
# ['NAME_CONTRACT_TYPE',
#  'AMT_ANNUITY',
#  'AMT_APPLICATION',
#  'AMT_CREDIT',
#  'AMT_DOWN_PAYMENT',
#  'AMT_GOODS_PRICE',
#  'HOUR_APPR_PROCESS_START',
#  'RATE_DOWN_PAYMENT',
#  'RATE_INTEREST_PRIMARY',
#  'RATE_INTEREST_PRIVILEGED',
#  'NAME_CONTRACT_STATUS',
#  'CODE_REJECT_REASON',
#  'CHANNEL_TYPE',
#  'SELLERPLACE_AREA',
#  'CNT_PAYMENT',
#  'DAYS_FIRST_DUE',
#  'DAYS_LAST_DUE_1ST_VERSION',
#  'DAYS_LAST_DUE',
#  'DAYS_TERMINATION',
#  'NFLAG_INSURED_ON_APPROVAL']

# %%
# Replace outliers with min or max values
for columnName in lesser:
    dataset1.loc[dataset1[columnName] < descriptive.loc['Lesser IQR', columnName], columnName] = descriptive.loc['Lesser IQR', columnName].astype(int)

for columnName in greater:
    dataset1.loc[dataset1[columnName] > descriptive.loc['Greater IQR', columnName], columnName] = descriptive.loc['Greater IQR', columnName].astype(int)

# %%
# Create a DataFrame to store descriptive statistics
descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', 'Q3:75%', 'Q4:100%', 'IQR', 'Lesser IQR', 'Greater IQR', 'min', 'max'], columns=dataset1.columns)

# Calculate additional statistics
for columnName in dataset1.columns:
    descriptive.loc["Mean", columnName] = dataset1[columnName].mean()
    descriptive.loc["Median", columnName] = dataset1[columnName].median()
    descriptive.loc["Mode", columnName] = dataset1[columnName].mode()[0]
    descriptive.loc['Q1:25%', columnName] = dataset1[columnName].quantile(0.25)
    descriptive.loc['Q2:50%', columnName] = dataset1[columnName].quantile(0.50)
    descriptive.loc['Q3:75%', columnName] = dataset1[columnName].quantile(0.75)
    descriptive.loc['min', columnName] = dataset1[columnName].min()
    descriptive.loc['max', columnName] = dataset1[columnName].max()
    descriptive.loc['Q4:100%', columnName] = dataset1[columnName].max()  # Add Q4:100% here

    iqr = descriptive.loc['Q3:75%', columnName] - descriptive.loc['Q1:25%', columnName]
    descriptive.loc['IQR', columnName] = iqr
    descriptive.loc['Lesser IQR', columnName] = descriptive.loc['Q1:25%', columnName] - 1.5 * iqr
    descriptive.loc['Greater IQR', columnName] = descriptive.loc['Q3:75%', columnName] + 1.5 * iqr

# %%
descriptive
# Out:
#                  SK_ID_PREV     SK_ID_CURR NAME_CONTRACT_TYPE   AMT_ANNUITY  \
# Mean         1923089.135331  278357.174099           0.668384  13338.377543
# Median            1923110.5       278714.5                1.0       11250.0
# Mode                1000001         187868                0.0       11250.0
# Q1:25%           1461857.25       189329.0                0.0    7547.09625
# Q2:50%            1923110.5       278714.5                1.0       11250.0
# Q3:75%           2384279.75       367514.0                1.0   16824.02625
# Q4:100%             2845382         456255                2.5   30739.42125
# IQR                922422.5       178185.0                1.0       9276.93
# Lesser IQR          78223.5       -77948.5               -1.5   -6368.29875
# Greater IQR       3767913.5       634791.5                2.5   30739.42125
# min                 1000001         100001                0.0           0.0
# max                 2845382         456255                2.5   30739.42125
#
#             AMT_APPLICATION     AMT_CREDIT AMT_DOWN_PAYMENT AMT_GOODS_PRICE  \
# Mean          126760.841716  147544.740282           1638.0   143101.490808
# Median              71046.0        80541.0           1638.0        112320.0
# Mode                    0.0            0.0           1638.0        112320.0
# Q1:25%              18720.0        24160.5           1638.0         67500.0
# Q2:50%              71046.0        80541.0           1638.0        112320.0
# Q3:75%             180360.0       216418.5           1638.0        180405.0
# Q4:100%            422820.0       504805.5           1638.0        349762.5
# IQR                161640.0       192258.0              0.0        112905.0
# Lesser IQR        -223740.0      -264226.5           1638.0       -101857.5
# Greater IQR        422820.0       504805.5           1638.0        349762.5
# min                     0.0            0.0           1638.0             0.0
# max                422820.0       504805.5           1638.0        349762.5
#
#             WEEKDAY_APPR_PROCESS_START HOUR_APPR_PROCESS_START  ...  \
# Mean                           3.01226               12.484809  ...
# Median                             3.0                    12.0  ...
# Mode                                 5                    11.0  ...
# Q1:25%                             1.0                    10.0  ...
# Q2:50%                             3.0                    12.0  ...
# Q3:75%                             5.0                    15.0  ...
# Q4:100%                              6                    22.5  ...
# IQR                                4.0                     5.0  ...
# Lesser IQR                        -5.0                     2.5  ...
# Greater IQR                       11.0                    22.5  ...
# min                                  0                     2.5  ...
# max                                  6                    22.5  ...
#
#             NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# Mean                    6.737651   12.818541         1.823614
# Median                      10.0        12.0              1.0
# Mode                          10        12.0                0
# Q1:25%                       4.0        10.0              0.0
# Q2:50%                      10.0        12.0              1.0
# Q3:75%                      10.0        16.0              3.0
# Q4:100%                       10        25.0                4
# IQR                          6.0         6.0              3.0
# Lesser IQR                  -5.0         1.0             -4.5
# Greater IQR                 19.0        25.0              7.5
# min                            0         1.0                0
# max                           10        25.0                4
#
#             PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# Mean                   6.947847           365243.0    -865.951943
# Median                      8.0           365243.0         -831.0
# Mode                          2           365243.0         -831.0
# Q1:25%                      2.0           365243.0        -1020.0
# Q2:50%                      8.0           365243.0         -831.0
# Q3:75%                     10.0           365243.0         -683.0
# Q4:100%                      16           365243.0         -177.5
# IQR                         8.0                0.0          337.0
# Lesser IQR                -10.0           365243.0        -1525.5
# Greater IQR                22.0           365243.0         -177.5
# min                           0           365243.0        -1525.5
# max                          16           365243.0         -177.5
#
#             DAYS_LAST_DUE_1ST_VERSION DAYS_LAST_DUE DAYS_TERMINATION  \
# Mean                      -395.247023   -561.779412       -522.18699
# Median                         -361.0        -537.0           -499.0
# Mode                           -361.0        -537.0           -499.0
# Q1:25%                         -580.0        -734.0           -695.0
# Q2:50%                         -361.0        -537.0           -499.0
# Q3:75%                         -187.0        -371.0           -334.0
# Q4:100%                         402.5         173.5            207.5
# IQR                             393.0         363.0            361.0
# Lesser IQR                    -1169.5       -1278.5          -1236.5
# Greater IQR                     402.5         173.5            207.5
# min                           -1169.5       -1278.5          -1236.5
# max                             402.5         173.5            207.5
#
#             NFLAG_INSURED_ON_APPROVAL
# Mean                              0.0
# Median                            0.0
# Mode                              0.0
# Q1:25%                            0.0
# Q2:50%                            0.0
# Q3:75%                            0.0
# Q4:100%                           0.0
# IQR                               0.0
# Lesser IQR                        0.0
# Greater IQR                       0.0
# min                               0.0
# max                               0.0
#
# [12 rows x 37 columns]

# %%
lesser = []
greater = []
# Check for outliers
for columnName in dataset1:
    if  descriptive.loc['Lesser IQR', columnName] > descriptive.loc['min', columnName]:
        lesser.append(columnName)

    if  descriptive.loc['Greater IQR', columnName] < descriptive.loc['max', columnName]:
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []
